# %%
from pymongo import MongoClient
import pandas as pd
import itertools
from functools import reduce


def create_pair_items(lst_items):
    return list(itertools.combinations(lst_items, 2))


mongo = MongoClient()
data = list(mongo.data_4.events.find({},{"userid": 1, "jobId": 1}))
meta_data = list(mongo.data_4.data.find({},{"tag": 0, "_id": 0}))
df = pd.DataFrame(data)
df_1 = df.groupby(["userid"]).aggregate({"jobId": list}).reset_index()
df_1["num_items"] = df_1.jobId.str.len()
df_1[df_1["num_items"] > 1]
item_item_data = reduce(lambda x, y: x + y, list([create_pair_items(i) for i in df_1.jobId.values.tolist()]))
df_2 = pd.DataFrame(item_item_data, columns=["item1", "item2"])
meta_df = pd.DataFrame(meta_data)
df_2 = df_2.merge(meta_df, how="left", left_on="item1", right_on="jobId")
df_2 = df_2.merge(meta_df, how="left", left_on="item2", right_on="jobId", suffixes=("_item1", "_item2"))

# %%
import os
import tempfile

# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

import tensorflow_recommenders as tfrs

# %%
tensor_slices = {
    "item1": df_2.item1.values.tolist(),
    "title_item1": df_2.title_item1.values.tolist(),
    "location_item1": df_2.location_item1.values.tolist(),
    "level_item1": df_2.level_item1.values.tolist(),
    "item2": df_2.item2.values.tolist(),
    "title_item2": df_2.title_item2.values.tolist(),
    "location_item2": df_2.location_item2.values.tolist(),
    "level_item2": df_2.level_item2.values.tolist(),
}

jobs = tf.data.Dataset.from_tensor_slices({
    "item2": meta_df.jobId.values.tolist(),
    "location_item2": meta_df.location.values.tolist(),
    "level_item2": meta_df.level.values.tolist(),
})

items = tf.data.Dataset.from_tensor_slices(tensor_slices)
# Out:
# 2024-02-05 10:42:55.407070: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-05 10:42:55.465191: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-05 10:42:55.465367: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-05 10:42:55.466400: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-05 10:42:55.466548: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-05 10:42:55.466678: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-05 10:42:55.533120: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-05 10:42:55.533251: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-05 10:42:55.533411: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-02-05 10:42:55.533493: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 718 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070, pci bus id: 0000:02:00.0, compute capability: 7.5

# %%
unique_items = np.unique(meta_df.jobId.values.tolist())
unique_location = np.unique(meta_df.location.values.tolist())
unique_level = np.unique(meta_df.level.values.tolist())

# %%
class Movie1Model(tf.keras.Model):

  def __init__(self):
    super().__init__()

    max_tokens = 10_000

    self.title_embedding = tf.keras.Sequential([
      tf.keras.layers.StringLookup(
          vocabulary=unique_items,mask_token=None),
      tf.keras.layers.Embedding(len(unique_items) + 1, 32)
    ])
    self.location_embedding = tf.keras.Sequential([
      tf.keras.layers.StringLookup(
          vocabulary=unique_location,mask_token=None),
      tf.keras.layers.Embedding(len(unique_location) + 1, 32)
    ])
    self.level_embedding = tf.keras.Sequential([
      tf.keras.layers.StringLookup(
          vocabulary=unique_level,mask_token=None),
      tf.keras.layers.Embedding(len(unique_level) + 1, 32)
    ])

  def call(self, features):
    return tf.concat([
        self.title_embedding(features["item1"]),
        self.location_embedding(features["location_item1"]),
        self.level_embedding(features["level_item1"])
    ], axis=1)


class Movie2Model(tf.keras.Model):

  def __init__(self):
    super().__init__()

    max_tokens = 10_000

    self.title_embedding = tf.keras.Sequential([
      tf.keras.layers.StringLookup(
          vocabulary=unique_items,mask_token=None),
      tf.keras.layers.Embedding(len(unique_items) + 1, 32)
    ])
    self.location_embedding = tf.keras.Sequential([
      tf.keras.layers.StringLookup(
          vocabulary=unique_location,mask_token=None),
      tf.keras.layers.Embedding(len(unique_location) + 1, 32)
    ])
    self.level_embedding = tf.keras.Sequential([
      tf.keras.layers.StringLookup(
          vocabulary=unique_level,mask_token=None),
      tf.keras.layers.Embedding(len(unique_level) + 1, 32)
    ])

  def call(self, features):
    return tf.concat([
        self.title_embedding(features["item2"]),
        self.location_embedding(features["location_item2"]),
        self.level_embedding(features["level_item2"])
    ], axis=1)

# %%
class QueryModel(tf.keras.Model):
  """Model for encoding movies."""

  def __init__(self, layer_sizes):
    """Model for encoding movies.

    Args:
      layer_sizes:
        A list of integers where the i-th entry represents the number of units
        the i-th layer contains.
    """
    super().__init__()

    self.embedding_model = Movie1Model()

    # Then construct the layers.
    self.dense_layers = tf.keras.Sequential()

    # Use the ReLU activation for all but the last layer.
    for layer_size in layer_sizes[:-1]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size, activation="relu"))

    # No activation for the last layer.
    for layer_size in layer_sizes[-1:]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size))

  def call(self, inputs):
    feature_embedding = self.embedding_model(inputs)
    return self.dense_layers(feature_embedding)


class CandidateModel(tf.keras.Model):
  """Model for encoding movies."""

  def __init__(self, layer_sizes):
    """Model for encoding movies.

    Args:
      layer_sizes:
        A list of integers where the i-th entry represents the number of units
        the i-th layer contains.
    """
    super().__init__()

    self.embedding_model = Movie2Model()

    # Then construct the layers.
    self.dense_layers = tf.keras.Sequential()

    # Use the ReLU activation for all but the last layer.
    for layer_size in layer_sizes[:-1]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size, activation="relu"))

    # No activation for the last layer.
    for layer_size in layer_sizes[-1:]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size))

  def call(self, inputs):
    feature_embedding = self.embedding_model(inputs)
    return self.dense_layers(feature_embedding)

# %%
class CFModel(tfrs.models.Model):

  def __init__(self, layer_sizes):
    super().__init__()
    self.query_model = QueryModel(layer_sizes)
    self.candidate_model = CandidateModel(layer_sizes)
    self.task = tfrs.tasks.Retrieval(
        metrics=tfrs.metrics.FactorizedTopK(
            candidates=jobs.batch(128).map(self.candidate_model),
        ),
    )

  def compute_loss(self, features, training=False):
    # We only pass the user id and timestamp features into the query model. This
    # is to ensure that the training inputs would have the same keys as the
    # query inputs. Otherwise the discrepancy in input structure would cause an
    # error when loading the query model after saving it.
    query_embeddings = self.query_model({
        "item1": features["item1"],
        "location_item1": features["location_item1"],
        "level_item1": features["level_item1"],
    })
    movie_embeddings = self.candidate_model({
        "item2": features["item2"],
        "location_item2": features["location_item2"],
        "level_item2": features["level_item2"],
    })

    return self.task(
        query_embeddings, movie_embeddings, compute_metrics=not training)

# %%
tf.random.set_seed(42)
shuffled = items.shuffle(100_000, seed=42, reshuffle_each_iteration=False)

train = shuffled.take(60_000)
test = shuffled.skip(80_000).take(20_000)

cached_train = train.shuffle(100_000).batch(2048)
cached_test = test.batch(4096).cache()

# %%
num_epochs = 300

model = CFModel([256, 128, 64])
model.compile(optimizer=tf.keras.optimizers.Adagrad(0.1))

one_layer_history = model.fit(
    cached_train,
    validation_data=cached_test,
    validation_freq=5,
    epochs=num_epochs,
    verbose=0)
# Out:
# 2023-03-24 13:57:38.362363: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x21da2060 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-03-24 13:57:38.362380: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 2070, Compute Capability 7.5
# 2023-03-24 13:57:38.365376: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-03-24 13:57:38.406941: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:38.432304: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-03-24 13:57:38.469142: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:38.639432: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:38.808655: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:38.951270: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:39.021754: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:39.091227: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:39.246371: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:39.327494: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:39.407460: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:39.480489: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:39.560784: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:39.638215: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:39.715842: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:39.848785: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:39.977612: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:40.098911: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:40.182301: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:40.266559: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:40.393915: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:40.636442: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:40.761359: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:40.902934: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:40.987925: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:41.174387: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:41.250587: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:41.326986: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:41.399969: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:41.785869: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:41.865252: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:41.950166: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:42.080121: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:42.239991: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:42.374981: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:42.627816: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:42.724238: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:42.798223: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:43.131050: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:43.410359: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:43.485505: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:43.976802: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:44.119482: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:44.192127: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:44.521136: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:44.748267: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:44.821318: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:46.129028: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:46.228196: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:46.302507: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:46.597442: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:46.817185: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:47.401364: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:48.351256: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:48.426473: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:48.869142: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:49.728777: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:50.033311: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:50.259566: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:50.725668: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:51.225917: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:53.038831: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:53.349289: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:55.263624: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:56.148070: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:57.058171: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:57.502358: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:57.778657: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:59.052090: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:57:59.428521: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:02.944163: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:06.976459: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:09.499895: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:13.432437: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:14.310469: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:15.929734: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:17.240086: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:17.710824: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:20.510451: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:23.671527: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:23.941615: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:45.981556: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:52.464603: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:58:57.807033: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:59:18.329585: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:59:23.495438: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:59:27.741191: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:59:28.203516: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:59:29.397169: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:59:29.868006: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-03-24 13:59:36.111307: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.

# %%
index = tfrs.layers.factorized_top_k.BruteForce(model.query_model, k=20)
index.index_from_dataset(
    jobs.batch(128).map(lambda x: (x["item2"], model.candidate_model(x))))
# Out:
# WARNING:tensorflow:From /home/spark/miniconda3/envs/recommend/lib/python3.9/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
Job_Leader_Data_Engineer_other_Leader_28XLZJ_, pred = index({"item1": np.array(["Job_Junior_Data_Analyst_DN_Junior_NE83IQ"]),
                 "location_item1": np.array(["DN"]),
                 "level_item1": np.array(["Junior"])
                })
pred.numpy()
# Out:
# array([[b'Job_Junior_Data_Analyst_DN_Junior_NE83IQ',
#         b'Job_Junior_Data_Analyst_DN_Junior_BVRE4S',
#         b'Job_Junior_Data_Analyst_DN_Junior_KBFFEL',
#         b'Job_Fresher_Data_Analyst_DN_Fresher_7BZI9S',
#         b'Job_Junior_Data_Analyst_other_Junior_5NGTDA',
#         b'Job_Junior_Data_Analyst_other_Junior_667A55',
#         b'Job_Fresher_Data_Analyst_DN_Fresher_D6F3AE',
#         b'Job_Junior_Data_Analyst_other_Junior_TPULME',
#         b'Job_Junior_Data_Analyst_other_Junior_3XPCDF',
#         b'Job_Fresher_Data_Analyst_DN_Fresher_RL9RQH',
#         b'Job_Fresher_Data_Analyst_other_Fresher_MPTE37',
#         b'Job_Junior_Data_Analyst_HN_Junior_D5PMAT',
#         b'Job_Junior_Data_Scientist_DN_Junior_39L9V4',
#         b'Job_Middle_Data_Analyst_other_Middle_3EUHOP',
#         b'Job_Middle_Data_Analyst_other_Middle_ZC51JS',
#         b'Job_Fresher_Data_Analyst_other_Fresher_50NE1S',
#         b'Job_Fresher_Data_Analyst_other_Fresher_V1E0HP',
#         b'Job_Fresher_Data_Analyst_other_Fresher_GQEHVS',
#         b'Job_Middle_Data_Scientist_other_Middle_E3JGU7',
#         b'Job_Junior_Data_Analyst_HCM_Junior_S21TYZ']], dtype=object)

# %%
unique_items
# Out:
# array(['Job_Fresher_Backend_Developer_HCM_Fresher_76GM1G',
#        'Job_Fresher_Backend_Developer_HCM_Fresher_EIC94O',
#        'Job_Fresher_Backend_Developer_HCM_Fresher_FZGHQV',
#        'Job_Fresher_Backend_Developer_HCM_Fresher_XNP1C4',
#        'Job_Fresher_Backend_Developer_HCM_Fresher_YU59N5',
#        'Job_Fresher_Backend_Developer_HN_Fresher_2P3ALT',
#        'Job_Fresher_Backend_Developer_HN_Fresher_CC8VJN',
#        'Job_Fresher_Backend_Developer_HN_Fresher_L22NC0',
#        'Job_Fresher_Backend_Developer_other_Fresher_3GRSYJ',
#        'Job_Fresher_Backend_Developer_other_Fresher_BRARX9',
#        'Job_Fresher_Backend_Developer_other_Fresher_IBM1QQ',
#        'Job_Fresher_Backend_Developer_other_Fresher_OW9IFH',
#        'Job_Fresher_Backend_Developer_other_Fresher_SRLBO5',
#        'Job_Fresher_Big_Data_Engineer_HCM_Fresher_19SU0T',
#        'Job_Fresher_Big_Data_Engineer_HCM_Fresher_1RJXI1',
#        'Job_Fresher_Big_Data_Engineer_HCM_Fresher_LWFD89',
#        'Job_Fresher_Big_Data_Engineer_HCM_Fresher_UP0TV3',
#        'Job_Fresher_Big_Data_Engineer_HN_Fresher_8WJ4Y7',
#        'Job_Fresher_Big_Data_Engineer_HN_Fresher_8YY6NO',
#        'Job_Fresher_Big_Data_Engineer_HN_Fresher_DXB6Z3',
#        'Job_Fresher_Big_Data_Engineer_HN_Fresher_QKHGHM',
#        'Job_Fresher_Big_Data_Engineer_HN_Fresher_XZDKA8',
#        'Job_Fresher_Big_Data_Engineer_other_Fresher_Y2GGAJ',
#        'Job_Fresher_Data_Analyst_DN_Fresher_7BZI9S',
#        'Job_Fresher_Data_Analyst_DN_Fresher_D6F3AE',
#        'Job_Fresher_Data_Analyst_DN_Fresher_RL9RQH',
#        'Job_Fresher_Data_Analyst_HCM_Fresher_E3BZRG',
#        'Job_Fresher_Data_Analyst_HN_Fresher_77XEOH',
#        'Job_Fresher_Data_Analyst_HN_Fresher_DJXGI5',
#        'Job_Fresher_Data_Analyst_other_Fresher_50NE1S',
#        'Job_Fresher_Data_Analyst_other_Fresher_GQEHVS',
#        'Job_Fresher_Data_Analyst_other_Fresher_MPTE37',
#        'Job_Fresher_Data_Analyst_other_Fresher_V1E0HP',
#        'Job_Fresher_Data_Engineer_HCM_Fresher_SM37LT',
#        'Job_Fresher_Data_Engineer_HN_Fresher_OPP283',
#        'Job_Fresher_Data_Engineer_other_Fresher_S1CGRO',
#        'Job_Fresher_Data_Scientist_DN_Fresher_322Z2N',
#        'Job_Fresher_Data_Scientist_DN_Fresher_FE94H5',
#        'Job_Fresher_Data_Scientist_HCM_Fresher_6Y43YG',
#        'Job_Fresher_Data_Scientist_HCM_Fresher_EUOKSS',
#        'Job_Fresher_Data_Scientist_HCM_Fresher_LT7Z9Z',
#        'Job_Fresher_Data_Scientist_HN_Fresher_BVQV5G',
#        'Job_Fresher_Data_Scientist_other_Fresher_2GKB9D',
#        'Job_Fresher_Data_Scientist_other_Fresher_K4YTMY',
#        'Job_Fresher_Data_Scientist_other_Fresher_W00Z14',
#        'Job_Fresher_Devops_Engineer_DN_Fresher_6RQXMD',
#        'Job_Fresher_Devops_Engineer_DN_Fresher_LOJB4Q',
#        'Job_Fresher_Devops_Engineer_other_Fresher_1J283U',
#        'Job_Fresher_Devops_Engineer_other_Fresher_DWH3YU',
#        'Job_Fresher_Devops_Engineer_other_Fresher_EJ7M9S',
#        'Job_Fresher_Devops_Engineer_other_Fresher_LW9FEG',
#        'Job_Fresher_Devops_Engineer_other_Fresher_O6E1M6',
#        'Job_Fresher_Devops_Engineer_other_Fresher_OB8O81',
#        'Job_Fresher_Devops_Engineer_other_Fresher_WXWPIQ',
#        'Job_Fresher_Devops_Engineer_other_Fresher_ZEGE37',
#        'Job_Fresher_Front-end_Developer_DN_Fresher_UX013F',
#        'Job_Fresher_Front-end_Developer_DN_Fresher_WX7AQJ',
#        'Job_Fresher_Front-end_Developer_HCM_Fresher_6SKSAP',
#        'Job_Fresher_Front-end_Developer_HCM_Fresher_JHQQQO',
#        'Job_Fresher_Front-end_Developer_HCM_Fresher_JQZ8IE',
#        'Job_Fresher_Front-end_Developer_HN_Fresher_0DICRB',
#        'Job_Fresher_Front-end_Developer_HN_Fresher_KJ61SL',
#        'Job_Fresher_Front-end_Developer_HN_Fresher_OHEGSJ',
#        'Job_Fresher_Front-end_Developer_HN_Fresher_YFWSSU',
#        'Job_Fresher_Front-end_Developer_other_Fresher_OA22WF',
#        'Job_Fresher_Front-end_Developer_other_Fresher_ORJKMM',
#        'Job_Fresher_Front-end_Developer_other_Fresher_S19PNZ',
#        'Job_Fresher_Front-end_Developer_other_Fresher_V2TXKN',
#        'Job_Fresher_Front-end_Developer_other_Fresher_XK3MYB',
#        'Job_Fresher_Fullstack_Developer_HCM_Fresher_HJDW3F',
#        'Job_Fresher_Fullstack_Developer_HCM_Fresher_MEU633',
#        'Job_Fresher_Fullstack_Developer_HN_Fresher_A6MN1K',
#        'Job_Fresher_Fullstack_Developer_HN_Fresher_L2P725',
#        'Job_Fresher_Fullstack_Developer_HN_Fresher_RS7L91',
#        'Job_Fresher_Fullstack_Developer_HN_Fresher_TLI196',
#        'Job_Fresher_Fullstack_Developer_other_Fresher_GB1G57',
#        'Job_Fresher_Fullstack_Developer_other_Fresher_I52ZGT',
#        'Job_Fresher_Fullstack_Developer_other_Fresher_OE2NTE',
#        'Job_Fresher_Fullstack_Developer_other_Fresher_WM5YTT',
#        'Job_Fresher_Fullstack_Developer_other_Fresher_ZJALU0',
#        'Job_Fresher_Java_Engineer_DN_Fresher_91JLZ8',
#        'Job_Fresher_Java_Engineer_HCM_Fresher_153J2Q',
#        'Job_Fresher_Java_Engineer_HCM_Fresher_484U94',
#        'Job_Fresher_Java_Engineer_HCM_Fresher_5QFWL8',
#        'Job_Fresher_Java_Engineer_HCM_Fresher_JEIYXK',
#        'Job_Fresher_Java_Engineer_HCM_Fresher_MAXNN3',
#        'Job_Fresher_Java_Engineer_HCM_Fresher_XZJDGN',
#        'Job_Fresher_Java_Engineer_HCM_Fresher_ZEOYGM',
#        'Job_Fresher_Java_Engineer_other_Fresher_9PW6VY',
#        'Job_Fresher_Java_Engineer_other_Fresher_EG2BLE',
#        'Job_Fresher_Java_Engineer_other_Fresher_UAOTA1',
#        'Job_Fresher_Machine_Learning_DN_Fresher_FLSC0G',
#        'Job_Fresher_Machine_Learning_DN_Fresher_L5V3X9',
#        'Job_Fresher_Machine_Learning_HCM_Fresher_11I71F',
#        'Job_Fresher_Machine_Learning_HCM_Fresher_4HQJ7X',
#        'Job_Fresher_Machine_Learning_HCM_Fresher_87LCUW',
#        'Job_Fresher_Machine_Learning_HCM_Fresher_FWXDJ2',
#        'Job_Fresher_Machine_Learning_HCM_Fresher_T2SR0A',
#        'Job_Fresher_Machine_Learning_HCM_Fresher_XLJE5K',
#        'Job_Fresher_NodeJS_Developer_DN_Fresher_GBKWPB',
#        'Job_Fresher_NodeJS_Developer_DN_Fresher_XQDV2R',
#        'Job_Fresher_NodeJS_Developer_HCM_Fresher_4JETJH',
#        'Job_Fresher_NodeJS_Developer_HCM_Fresher_90TC4S',
#        'Job_Fresher_NodeJS_Developer_HCM_Fresher_GS9B9M',
#        'Job_Fresher_NodeJS_Developer_HCM_Fresher_PB40LH',
#        'Job_Fresher_NodeJS_Developer_HN_Fresher_RNJIF0',
#        'Job_Fresher_NodeJS_Developer_other_Fresher_8T0RDK',
#        'Job_Fresher_NodeJS_Developer_other_Fresher_B1F3LE',
#        'Job_Fresher_NodeJS_Developer_other_Fresher_LCNO13',
#        'Job_Fresher_NodeJS_Developer_other_Fresher_PJZZPQ',
#        'Job_Fresher_NodeJS_Developer_other_Fresher_RH8E05',
#        'Job_Fresher_Python_Developer_HCM_Fresher_IMYUG0',
#        'Job_Fresher_Python_Developer_HN_Fresher_Q59HF1',
#        'Job_Fresher_Python_Developer_HN_Fresher_SA1AWP',
#        'Job_Fresher_Python_Developer_other_Fresher_GG3OF9',
#        'Job_Fresher_Python_Developer_other_Fresher_IFWHFX',
#        'Job_Fresher_Python_Developer_other_Fresher_PDDKFS',
#        'Job_Fresher_Python_Developer_other_Fresher_QJPE5T',
#        'Job_Junior_Backend_Developer_HCM_Junior_BRDHCH',
#        'Job_Junior_Backend_Developer_HCM_Junior_EA2ZNI',
#        'Job_Junior_Backend_Developer_other_Junior_0QWH6A',
#        'Job_Junior_Backend_Developer_other_Junior_AWHQXY',
#        'Job_Junior_Backend_Developer_other_Junior_O0EJ8N',
#        'Job_Junior_Big_Data_Engineer_HCM_Junior_C7US7I',
#        'Job_Junior_Big_Data_Engineer_HCM_Junior_D962T4',
#        'Job_Junior_Big_Data_Engineer_HCM_Junior_DR6LXO',
#        'Job_Junior_Big_Data_Engineer_HCM_Junior_TCRSSW',
#        'Job_Junior_Big_Data_Engineer_HN_Junior_DO3U66',
#        'Job_Junior_Big_Data_Engineer_HN_Junior_K5AFNT',
#        'Job_Junior_Big_Data_Engineer_HN_Junior_RJ1AT7',
#        'Job_Junior_Big_Data_Engineer_HN_Junior_VWXGRO',
#        'Job_Junior_Big_Data_Engineer_other_Junior_G4I9C6',
#        'Job_Junior_Big_Data_Engineer_other_Junior_KPNP0B',
#        'Job_Junior_Big_Data_Engineer_other_Junior_MTKGFB',
#        'Job_Junior_Big_Data_Engineer_other_Junior_MTRIXF',
#        'Job_Junior_Big_Data_Engineer_other_Junior_N4MGLO',
#        'Job_Junior_Big_Data_Engineer_other_Junior_Q38W3Z',
#        'Job_Junior_Data_Analyst_DN_Junior_BVRE4S',
#        'Job_Junior_Data_Analyst_DN_Junior_KBFFEL',
#        'Job_Junior_Data_Analyst_DN_Junior_NE83IQ',
#        'Job_Junior_Data_Analyst_HCM_Junior_5GHANM',
#        'Job_Junior_Data_Analyst_HCM_Junior_DYMOIQ',
#        'Job_Junior_Data_Analyst_HCM_Junior_PS1K2A',
#        'Job_Junior_Data_Analyst_HCM_Junior_Q6PGBV',
#        'Job_Junior_Data_Analyst_HCM_Junior_S21TYZ',
#        'Job_Junior_Data_Analyst_HCM_Junior_WKBDO5',
#        'Job_Junior_Data_Analyst_HN_Junior_D5PMAT',
#        'Job_Junior_Data_Analyst_HN_Junior_J81IRM',
#        'Job_Junior_Data_Analyst_other_Junior_3XPCDF',
#        'Job_Junior_Data_Analyst_other_Junior_5NGTDA',
#        'Job_Junior_Data_Analyst_other_Junior_667A55',
#        'Job_Junior_Data_Analyst_other_Junior_TPULME',
#        'Job_Junior_Data_Engineer_HCM_Junior_509PZE',
#        'Job_Junior_Data_Engineer_HCM_Junior_F1M68S',
#        'Job_Junior_Data_Engineer_HN_Junior_Z1QT8P',
#        'Job_Junior_Data_Engineer_other_Junior_40WZUF',
#        'Job_Junior_Data_Engineer_other_Junior_5DSYC8',
#        'Job_Junior_Data_Engineer_other_Junior_6K4WFW',
#        'Job_Junior_Data_Engineer_other_Junior_CT8Q1G',
#        'Job_Junior_Data_Scientist_DN_Junior_39L9V4',
#        'Job_Junior_Data_Scientist_DN_Junior_7F5FM7',
#        'Job_Junior_Data_Scientist_HCM_Junior_APB0YL',
#        'Job_Junior_Data_Scientist_HCM_Junior_DTCI73',
#        'Job_Junior_Data_Scientist_HCM_Junior_I3CR00',
#        'Job_Junior_Data_Scientist_HCM_Junior_IVL7RA',
#        'Job_Junior_Data_Scientist_HCM_Junior_LTXYVO',
#        'Job_Junior_Data_Scientist_HCM_Junior_Q46O1D',
#        'Job_Junior_Data_Scientist_HCM_Junior_QLSMB4',
#        'Job_Junior_Data_Scientist_HCM_Junior_Y8YRYZ',
#        'Job_Junior_Data_Scientist_HN_Junior_3FUYS5',
#        'Job_Junior_Data_Scientist_HN_Junior_4PTNMT',
#        'Job_Junior_Data_Scientist_HN_Junior_NXA7A7',
#        'Job_Junior_Data_Scientist_HN_Junior_QCL9EF',
#        'Job_Junior_Data_Scientist_other_Junior_DL5R62',
#        'Job_Junior_Data_Scientist_other_Junior_IPIZ3M',
#        'Job_Junior_Devops_Engineer_DN_Junior_OOC29L',
#        'Job_Junior_Devops_Engineer_DN_Junior_XDCD5G',
#        'Job_Junior_Devops_Engineer_HCM_Junior_BIS7WG',
#        'Job_Junior_Devops_Engineer_HCM_Junior_HOYC8N',
#        'Job_Junior_Devops_Engineer_HCM_Junior_TDFU16',
#        'Job_Junior_Devops_Engineer_HN_Junior_K160Y6',
#        'Job_Junior_Devops_Engineer_other_Junior_5Y3Q92',
#        'Job_Junior_Devops_Engineer_other_Junior_7CCUM8',
#        'Job_Junior_Devops_Engineer_other_Junior_Q066MP',
#        'Job_Junior_Front-end_Developer_DN_Junior_QZ9230',
#        'Job_Junior_Front-end_Developer_HCM_Junior_FDBQNV',
#        'Job_Junior_Front-end_Developer_HCM_Junior_UFYE4R',
#        'Job_Junior_Front-end_Developer_HCM_Junior_VWQA96',
#        'Job_Junior_Front-end_Developer_HN_Junior_2T0Q3T',
#        'Job_Junior_Front-end_Developer_HN_Junior_H624M6',
#        'Job_Junior_Front-end_Developer_HN_Junior_ILJ3OU',
#        'Job_Junior_Front-end_Developer_HN_Junior_L94HNI',
#        'Job_Junior_Front-end_Developer_HN_Junior_Q1AWII',
#        'Job_Junior_Front-end_Developer_other_Junior_3TCZNW',
#        'Job_Junior_Front-end_Developer_other_Junior_QMHV22',
#        'Job_Junior_Front-end_Developer_other_Junior_UEGRRZ',
#        'Job_Junior_Fullstack_Developer_DN_Junior_4AJ6YX',
#        'Job_Junior_Fullstack_Developer_HCM_Junior_1NW55V',
#        'Job_Junior_Fullstack_Developer_HCM_Junior_CZLHYZ',
#        'Job_Junior_Fullstack_Developer_HCM_Junior_DQK610',
#        'Job_Junior_Fullstack_Developer_HCM_Junior_I5OL1Z',
#        'Job_Junior_Fullstack_Developer_HCM_Junior_SW8Y6F',
#        'Job_Junior_Fullstack_Developer_HCM_Junior_WI90QV',
#        'Job_Junior_Fullstack_Developer_HN_Junior_K8SB85',
#        'Job_Junior_Fullstack_Developer_other_Junior_0QNLOW',
#        'Job_Junior_Fullstack_Developer_other_Junior_1VAKND',
#        'Job_Junior_Fullstack_Developer_other_Junior_6KPZGQ',
#        'Job_Junior_Fullstack_Developer_other_Junior_9NCEOC',
#        'Job_Junior_Fullstack_Developer_other_Junior_9SK7IH',
#        'Job_Junior_Fullstack_Developer_other_Junior_LRHH2L',
#        'Job_Junior_Java_Engineer_HCM_Junior_RZ23WL',
#        'Job_Junior_Java_Engineer_HCM_Junior_TEAU9E',
#        'Job_Junior_Java_Engineer_HN_Junior_2M1PMZ',
#        'Job_Junior_Java_Engineer_HN_Junior_FX3HBC',
#        'Job_Junior_Java_Engineer_HN_Junior_XTDDT7',
#        'Job_Junior_Java_Engineer_other_Junior_9HIAI8',
#        'Job_Junior_Java_Engineer_other_Junior_LZUKLB',
#        'Job_Junior_Java_Engineer_other_Junior_M4ZGGB',
#        'Job_Junior_Java_Engineer_other_Junior_NKWVCT',
#        'Job_Junior_Java_Engineer_other_Junior_PN569D',
#        'Job_Junior_Java_Engineer_other_Junior_QLRPXP',
#        'Job_Junior_Java_Engineer_other_Junior_VL1Y6I',
#        'Job_Junior_Java_Engineer_other_Junior_X19O7O',
#        'Job_Junior_Java_Engineer_other_Junior_XGYM92',
#        'Job_Junior_Machine_Learning_DN_Junior_VTWUF1',
#        'Job_Junior_Machine_Learning_HCM_Junior_1TN4DP',
#        'Job_Junior_Machine_Learning_HCM_Junior_AG6222',
#        'Job_Junior_Machine_Learning_HCM_Junior_B8JLV3',
#        'Job_Junior_Machine_Learning_HCM_Junior_E0N7ES',
#        'Job_Junior_Machine_Learning_HN_Junior_IIPS6A',
#        'Job_Junior_Machine_Learning_HN_Junior_SMET6F',
#        'Job_Junior_Machine_Learning_HN_Junior_ZRHPDL',
#        'Job_Junior_Machine_Learning_other_Junior_NT2KPR',
#        'Job_Junior_Machine_Learning_other_Junior_T7Y8NQ',
#        'Job_Junior_NodeJS_Developer_DN_Junior_2QWO3K',
#        'Job_Junior_NodeJS_Developer_HCM_Junior_AMF0V4',
#        'Job_Junior_NodeJS_Developer_HCM_Junior_IKVGAU',
#        'Job_Junior_NodeJS_Developer_HN_Junior_9OFTDS',
#        'Job_Junior_NodeJS_Developer_HN_Junior_RW2R2M',
#        'Job_Junior_NodeJS_Developer_HN_Junior_W8ZV60',
#        'Job_Junior_NodeJS_Developer_HN_Junior_XXEEGW',
#        'Job_Junior_NodeJS_Developer_other_Junior_1M8957',
#        'Job_Junior_NodeJS_Developer_other_Junior_6TSBLJ',
#        'Job_Junior_NodeJS_Developer_other_Junior_BHDVOS',
#        'Job_Junior_NodeJS_Developer_other_Junior_G0GX39',
#        'Job_Junior_Python_Developer_DN_Junior_P49WOA',
#        'Job_Junior_Python_Developer_HCM_Junior_27ZBSZ',
#        'Job_Junior_Python_Developer_HCM_Junior_KW1HB4',
#        'Job_Junior_Python_Developer_HCM_Junior_S2MY8B',
#        'Job_Junior_Python_Developer_HCM_Junior_WTHXU6',
#        'Job_Junior_Python_Developer_HN_Junior_93UFYO',
#        'Job_Junior_Python_Developer_HN_Junior_IH4DJD',
#        'Job_Junior_Python_Developer_HN_Junior_RQQW3X',
#        'Job_Junior_Python_Developer_other_Junior_9M8TN0',
#        'Job_Junior_Python_Developer_other_Junior_EVB8GL',
#        'Job_Junior_Python_Developer_other_Junior_MDCUH2',
#        'Job_Leader_Backend_Developer_DN_Leader_5S3MEZ',
#        'Job_Leader_Big_Data_Engineer_HCM_Leader_UY88EU',
#        'Job_Leader_Big_Data_Engineer_other_Leader_1MUQLI',
#        'Job_Leader_Data_Analyst_HN_Leader_LTVTYK',
#        'Job_Leader_Data_Engineer_DN_Leader_T8GCN9',
#        'Job_Leader_Data_Engineer_HCM_Leader_LOAVVW',
#        'Job_Leader_Data_Engineer_HCM_Leader_RSS47O',
#        'Job_Leader_Data_Engineer_HN_Leader_KPZ7PC',
#        'Job_Leader_Data_Scientist_HCM_Leader_FPYOFE',
#        'Job_Leader_Data_Scientist_HN_Leader_0FANM2',
#        'Job_Leader_Devops_Engineer_DN_Leader_F6HD4P',
#        'Job_Leader_Devops_Engineer_DN_Leader_WQ6DIA',
#        'Job_Leader_Devops_Engineer_HCM_Leader_1TGVL4',
#        'Job_Leader_Devops_Engineer_HCM_Leader_BW1XQH',
#        'Job_Leader_Devops_Engineer_HCM_Leader_HC7FVB',
#        'Job_Leader_Devops_Engineer_other_Leader_B1GSJX',
#        'Job_Leader_Devops_Engineer_other_Leader_DTM9OW',
#        'Job_Leader_Front-end_Developer_HCM_Leader_YLEA4H',
#        'Job_Leader_Fullstack_Developer_HCM_Leader_ARJNQR',
#        'Job_Leader_Fullstack_Developer_HCM_Leader_XJPHP7',
#        'Job_Leader_Fullstack_Developer_other_Leader_25CY0T',
#        'Job_Leader_Fullstack_Developer_other_Leader_6B5JI0',
#        'Job_Leader_Fullstack_Developer_other_Leader_JV8915',
#        'Job_Leader_Fullstack_Developer_other_Leader_NWJEYT',
#        'Job_Leader_Java_Engineer_HCM_Leader_59B0CV',
#        'Job_Leader_Java_Engineer_HN_Leader_8YQRT2',
#        'Job_Leader_Java_Engineer_other_Leader_LKHMTY',
#        'Job_Leader_NodeJS_Developer_HCM_Leader_6C7Z4G',
#        'Job_Leader_NodeJS_Developer_HCM_Leader_CME1OL',
#        'Job_Leader_NodeJS_Developer_other_Leader_S3ALL3',
#        'Job_Leader_NodeJS_Developer_other_Leader_SKEPQV',
#        'Job_Leader_NodeJS_Developer_other_Leader_W9OYIX',
#        'Job_Leader_Python_Developer_DN_Leader_M9IYPB',
#        'Job_Leader_Python_Developer_HCM_Leader_D420L9',
#        'Job_Leader_Python_Developer_HCM_Leader_XFHYJH',
#        'Job_Leader_Python_Developer_other_Leader_FUJCVB',
#        'Job_Middle_Backend_Developer_HCM_Middle_BUJ7HQ',
#        'Job_Middle_Backend_Developer_HCM_Middle_VBEFBN',
#        'Job_Middle_Backend_Developer_HN_Middle_MWHK01',
#        'Job_Middle_Backend_Developer_HN_Middle_QVSH88',
#        'Job_Middle_Backend_Developer_other_Middle_IAC9FE',
#        'Job_Middle_Backend_Developer_other_Middle_QFJDN3',
#        'Job_Middle_Backend_Developer_other_Middle_YYAI6F',
#        'Job_Middle_Big_Data_Engineer_HCM_Middle_0MXSO4',
#        'Job_Middle_Big_Data_Engineer_HCM_Middle_3SZAST',
#        'Job_Middle_Big_Data_Engineer_HCM_Middle_ELJY5M',
#        'Job_Middle_Big_Data_Engineer_other_Middle_1W01E6',
#        'Job_Middle_Big_Data_Engineer_other_Middle_8IQMX2',
#        'Job_Middle_Big_Data_Engineer_other_Middle_YI5E1T',
#        'Job_Middle_Big_Data_Engineer_other_Middle_ZAWMT5',
#        'Job_Middle_Data_Analyst_HCM_Middle_2XCWL2',
#        'Job_Middle_Data_Analyst_HCM_Middle_5XFM6G',
#        'Job_Middle_Data_Analyst_HCM_Middle_6B8YWX',
#        'Job_Middle_Data_Analyst_HCM_Middle_6CHZUB',
#        'Job_Middle_Data_Analyst_HCM_Middle_8FKACZ',
#        'Job_Middle_Data_Analyst_HCM_Middle_9W9K9F',
#        'Job_Middle_Data_Analyst_HCM_Middle_BHKRPW',
#        'Job_Middle_Data_Analyst_HCM_Middle_G3C64B',
#        'Job_Middle_Data_Analyst_HCM_Middle_O6GL2O',
#        'Job_Middle_Data_Analyst_HCM_Middle_RBJ4S4',
#        'Job_Middle_Data_Analyst_HN_Middle_C5Y4FA',
#        'Job_Middle_Data_Analyst_other_Middle_3EUHOP',
#        'Job_Middle_Data_Analyst_other_Middle_ZC51JS',
#        'Job_Middle_Data_Engineer_DN_Middle_PA1JLD',
#        'Job_Middle_Data_Engineer_DN_Middle_PI6WBB',
#        'Job_Middle_Data_Engineer_HCM_Middle_89RV3P',
#        'Job_Middle_Data_Engineer_HCM_Middle_I7DW19',
#        'Job_Middle_Data_Engineer_HCM_Middle_LZ029C',
#        'Job_Middle_Data_Engineer_other_Middle_9FKXMZ',
#        'Job_Middle_Data_Scientist_HCM_Middle_29JBPP',
#        'Job_Middle_Data_Scientist_HCM_Middle_RIVQZM',
#        'Job_Middle_Data_Scientist_HN_Middle_1FNUHF',
#        'Job_Middle_Data_Scientist_HN_Middle_QLQTNY',
#        'Job_Middle_Data_Scientist_other_Middle_11HC05',
#        'Job_Middle_Data_Scientist_other_Middle_E3JGU7',
#        'Job_Middle_Data_Scientist_other_Middle_IXGO10',
#        'Job_Middle_Data_Scientist_other_Middle_ZE7ZET',
#        'Job_Middle_Devops_Engineer_DN_Middle_80ZKUW',
#        'Job_Middle_Devops_Engineer_HCM_Middle_XM196A',
#        'Job_Middle_Devops_Engineer_HN_Middle_3HOZW0',
#        'Job_Middle_Devops_Engineer_HN_Middle_B81KDR',
#        'Job_Middle_Devops_Engineer_other_Middle_MYUQPH',
#        'Job_Middle_Devops_Engineer_other_Middle_O2BBAF',
#        'Job_Middle_Devops_Engineer_other_Middle_SZAPIF',
#        'Job_Middle_Devops_Engineer_other_Middle_ZX6VL6',
#        'Job_Middle_Front-end_Developer_DN_Middle_B0JL1U',
#        'Job_Middle_Front-end_Developer_DN_Middle_ZL5GBG',
#        'Job_Middle_Front-end_Developer_HCM_Middle_1VBV7F',
#        'Job_Middle_Front-end_Developer_HCM_Middle_9OWOM3',
#        'Job_Middle_Front-end_Developer_HCM_Middle_MPBQJJ',
#        'Job_Middle_Front-end_Developer_other_Middle_1P5ZB3',
#        'Job_Middle_Front-end_Developer_other_Middle_36R2IL',
#        'Job_Middle_Front-end_Developer_other_Middle_KTZZ21',
#        'Job_Middle_Front-end_Developer_other_Middle_LWRM34',
#        'Job_Middle_Front-end_Developer_other_Middle_M5BWZZ',
#        'Job_Middle_Fullstack_Developer_HCM_Middle_9VQKRT',
#        'Job_Middle_Fullstack_Developer_HCM_Middle_C488NQ',
#        'Job_Middle_Fullstack_Developer_HCM_Middle_DYC302',
#        'Job_Middle_Fullstack_Developer_HCM_Middle_E7HZUP',
#        'Job_Middle_Fullstack_Developer_HN_Middle_906PGR',
#        'Job_Middle_Fullstack_Developer_HN_Middle_GH5PH9',
#        'Job_Middle_Fullstack_Developer_other_Middle_C92N8D',
#        'Job_Middle_Fullstack_Developer_other_Middle_CBTWUS',
#        'Job_Middle_Fullstack_Developer_other_Middle_LZ4ZFO',
#        'Job_Middle_Java_Engineer_HCM_Middle_G0SIA8',
#        'Job_Middle_Java_Engineer_HCM_Middle_PZGWAY',
#        'Job_Middle_Java_Engineer_HCM_Middle_RFH0PY',
#        'Job_Middle_Java_Engineer_HN_Middle_95XGCR',
#        'Job_Middle_Java_Engineer_HN_Middle_9WQV9H',
#        'Job_Middle_Java_Engineer_other_Middle_TJE8A1',
#        'Job_Middle_Java_Engineer_other_Middle_X9N1IE',
#        'Job_Middle_Machine_Learning_HCM_Middle_2CUS8O',
#        'Job_Middle_Machine_Learning_HCM_Middle_DU5UD6',
#        'Job_Middle_Machine_Learning_HCM_Middle_Q5S68F',
#        'Job_Middle_Machine_Learning_HCM_Middle_YA6T1C',
#        'Job_Middle_Machine_Learning_HN_Middle_1DMYWT',
#        'Job_Middle_Machine_Learning_HN_Middle_4PDB3T',
#        'Job_Middle_Machine_Learning_HN_Middle_AUNCQ0',
#        'Job_Middle_Machine_Learning_HN_Middle_J4HABT',
#        'Job_Middle_Machine_Learning_other_Middle_2LWZGH',
#        'Job_Middle_Machine_Learning_other_Middle_7Z7NRB',
#        'Job_Middle_Machine_Learning_other_Middle_HTX0H1',
#        'Job_Middle_Machine_Learning_other_Middle_Z5W8EL',
#        'Job_Middle_NodeJS_Developer_DN_Middle_RS32IG',
#        'Job_Middle_NodeJS_Developer_HCM_Middle_BONL0D',
#        'Job_Middle_NodeJS_Developer_HCM_Middle_PALH6E',
#        'Job_Middle_NodeJS_Developer_HCM_Middle_URRYOQ',
#        'Job_Middle_NodeJS_Developer_HCM_Middle_XGFL4F',
#        'Job_Middle_NodeJS_Developer_HN_Middle_M9LE6K',
#        'Job_Middle_NodeJS_Developer_HN_Middle_T7Y0AM',
#        'Job_Middle_NodeJS_Developer_other_Middle_1ZGJBQ',
#        'Job_Middle_NodeJS_Developer_other_Middle_AC9QLH',
#        'Job_Middle_NodeJS_Developer_other_Middle_J41CDA',
#        'Job_Middle_Python_Developer_DN_Middle_2ELBWZ',
#        'Job_Middle_Python_Developer_DN_Middle_CQPGO8',
#        'Job_Middle_Python_Developer_HCM_Middle_FFPSRJ',
#        'Job_Middle_Python_Developer_HCM_Middle_OL8OPG',
#        'Job_Middle_Python_Developer_HN_Middle_1HS0W0',
#        'Job_Middle_Python_Developer_other_Middle_59WFFE',
#        'Job_Middle_Python_Developer_other_Middle_GDF10T',
#        'Job_Middle_Python_Developer_other_Middle_KD0AA2',
#        'Job_Middle_Python_Developer_other_Middle_NSMKXZ',
#        'Job_Senior_Backend_Developer_HCM_Senior_9AD1YT',
#        'Job_Senior_Backend_Developer_HCM_Senior_VROL8L',
#        'Job_Senior_Backend_Developer_HN_Senior_1TYDJX',
#        'Job_Senior_Backend_Developer_HN_Senior_UG7GH6',
#        'Job_Senior_Backend_Developer_other_Senior_8NK5A0',
#        'Job_Senior_Backend_Developer_other_Senior_RYU8R6',
#        'Job_Senior_Backend_Developer_other_Senior_SFHY5W',
#        'Job_Senior_Big_Data_Engineer_HCM_Senior_EJMCUE',
#        'Job_Senior_Big_Data_Engineer_HCM_Senior_G49SL4',
#        'Job_Senior_Big_Data_Engineer_HCM_Senior_WGTVVR',
#        'Job_Senior_Big_Data_Engineer_HN_Senior_26R879',
#        'Job_Senior_Big_Data_Engineer_HN_Senior_B7B5S9',
#        'Job_Senior_Big_Data_Engineer_HN_Senior_EOXG9Q',
#        'Job_Senior_Big_Data_Engineer_HN_Senior_MPVR3Z',
#        'Job_Senior_Big_Data_Engineer_HN_Senior_TSTUD4',
#        'Job_Senior_Big_Data_Engineer_other_Senior_3SWFCV',
#        'Job_Senior_Data_Analyst_DN_Senior_4SK2RZ',
#        'Job_Senior_Data_Analyst_HCM_Senior_10UUH7',
#        'Job_Senior_Data_Analyst_HCM_Senior_HS3YPX',
#        'Job_Senior_Data_Analyst_HN_Senior_IWTWQ2',
#        'Job_Senior_Data_Analyst_HN_Senior_O0IMAX',
#        'Job_Senior_Data_Analyst_HN_Senior_ZQS08U',
#        'Job_Senior_Data_Analyst_other_Senior_7LNX1T',
#        'Job_Senior_Data_Analyst_other_Senior_D6E4IR',
#        'Job_Senior_Data_Analyst_other_Senior_XQ0IE0',
#        'Job_Senior_Data_Engineer_DN_Senior_EPW5FX',
#        'Job_Senior_Data_Engineer_DN_Senior_MYLF9F',
#        'Job_Senior_Data_Engineer_DN_Senior_TVCKJ8',
#        'Job_Senior_Data_Engineer_HCM_Senior_KSID1X',
#        'Job_Senior_Data_Engineer_HCM_Senior_UP7QPF',
#        'Job_Senior_Data_Engineer_HN_Senior_A8KU9Y',
#        'Job_Senior_Data_Engineer_HN_Senior_MIT8WC',
#        'Job_Senior_Data_Engineer_HN_Senior_TCKRLK',
#        'Job_Senior_Data_Engineer_other_Senior_2S85NR',
#        'Job_Senior_Data_Engineer_other_Senior_D6JXTV',
#        'Job_Senior_Data_Engineer_other_Senior_EI880N',
#        'Job_Senior_Data_Scientist_HCM_Senior_BSMYL0',
#        'Job_Senior_Data_Scientist_HCM_Senior_RT6A7M',
#        'Job_Senior_Devops_Engineer_HCM_Senior_1L42H7',
#        'Job_Senior_Devops_Engineer_HCM_Senior_FSNW8X',
#        'Job_Senior_Devops_Engineer_HCM_Senior_JWDEPT',
#        'Job_Senior_Devops_Engineer_HCM_Senior_M2MZCT',
#        'Job_Senior_Devops_Engineer_HN_Senior_6DXBEM',
#        'Job_Senior_Devops_Engineer_other_Senior_0QDYVQ',
#        'Job_Senior_Devops_Engineer_other_Senior_D57GW0',
#        'Job_Senior_Front-end_Developer_HCM_Senior_J5X1O3',
#        'Job_Senior_Front-end_Developer_HCM_Senior_JJ942G',
#        'Job_Senior_Front-end_Developer_HCM_Senior_YR68NB',
#        'Job_Senior_Front-end_Developer_HN_Senior_D54G4T',
#        'Job_Senior_Front-end_Developer_HN_Senior_PULW2D',
#        'Job_Senior_Front-end_Developer_other_Senior_A0JXRC',
#        'Job_Senior_Front-end_Developer_other_Senior_CL58CV',
#        'Job_Senior_Front-end_Developer_other_Senior_NTGFPH',
#        'Job_Senior_Front-end_Developer_other_Senior_YYVKKQ',
#        'Job_Senior_Front-end_Developer_other_Senior_ZKVW8S',
#        'Job_Senior_Fullstack_Developer_DN_Senior_DCI8UP',
#        'Job_Senior_Fullstack_Developer_DN_Senior_V9PRUR',
#        'Job_Senior_Fullstack_Developer_HCM_Senior_3PPZBH',
#        'Job_Senior_Fullstack_Developer_HCM_Senior_6M7BKV',
#        'Job_Senior_Fullstack_Developer_HCM_Senior_AUPBNA',
#        'Job_Senior_Fullstack_Developer_HCM_Senior_T42NPL',
#        'Job_Senior_Fullstack_Developer_HN_Senior_TXAL1C',
#        'Job_Senior_Fullstack_Developer_HN_Senior_TZSAT6',
#        'Job_Senior_Fullstack_Developer_HN_Senior_WV4Z0H',
#        'Job_Senior_Fullstack_Developer_other_Senior_6V6XK1',
#        'Job_Senior_Fullstack_Developer_other_Senior_B7CWDQ',
#        'Job_Senior_Fullstack_Developer_other_Senior_RNJ122',
#        'Job_Senior_Fullstack_Developer_other_Senior_UEBK5T',
#        'Job_Senior_Fullstack_Developer_other_Senior_XU0K44',
#        'Job_Senior_Java_Engineer_DN_Senior_8UO6SF',
#        'Job_Senior_Java_Engineer_DN_Senior_OMLEZP',
#        'Job_Senior_Java_Engineer_HCM_Senior_CCAL1H',
#        'Job_Senior_Java_Engineer_HCM_Senior_I1M6KB',
#        'Job_Senior_Java_Engineer_HCM_Senior_KRLVB5',
#        'Job_Senior_Java_Engineer_HN_Senior_2OFSHX',
#        'Job_Senior_Java_Engineer_HN_Senior_8F1A9E',
#        'Job_Senior_Java_Engineer_HN_Senior_EEKB0H',
#        'Job_Senior_Java_Engineer_HN_Senior_J8DHI5',
#        'Job_Senior_Java_Engineer_HN_Senior_Q4D0R3',
#        'Job_Senior_Java_Engineer_HN_Senior_RWAU0E',
#        'Job_Senior_Java_Engineer_other_Senior_17I0F1',
#        'Job_Senior_Java_Engineer_other_Senior_57YJFX',
#        'Job_Senior_Java_Engineer_other_Senior_611CPY',
#        'Job_Senior_Java_Engineer_other_Senior_HV1N6O',
#        'Job_Senior_Java_Engineer_other_Senior_NKOYMI',
#        'Job_Senior_Machine_Learning_HCM_Senior_SVOMX0',
#        'Job_Senior_Machine_Learning_HCM_Senior_VUZ1BL',
#        'Job_Senior_Machine_Learning_HN_Senior_CYI5H4',
#        'Job_Senior_Machine_Learning_other_Senior_79Z5AL',
#        'Job_Senior_Machine_Learning_other_Senior_XWTQNS',
#        'Job_Senior_NodeJS_Developer_HCM_Senior_T7P9RY',
#        'Job_Senior_NodeJS_Developer_HN_Senior_33WBFD',
#        'Job_Senior_NodeJS_Developer_HN_Senior_NVE6EK',
#        'Job_Senior_NodeJS_Developer_other_Senior_EQ7AO5',
#        'Job_Senior_NodeJS_Developer_other_Senior_HKKGTE',
#        'Job_Senior_Python_Developer_DN_Senior_035I9Z',
#        'Job_Senior_Python_Developer_DN_Senior_2WC858',
#        'Job_Senior_Python_Developer_HCM_Senior_F57GXX',
#        'Job_Senior_Python_Developer_HCM_Senior_I0VZQB',
#        'Job_Senior_Python_Developer_other_Senior_5QGDX3',
#        'Job_Senior_Python_Developer_other_Senior_6TVVA5',
#        'Job_Senior_Python_Developer_other_Senior_LEXLL7'], dtype='<U52')
