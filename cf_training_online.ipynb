# %%
import os
import tempfile
import matplotlib.pyplot as plt

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_recommenders as tfrs

plt.style.use('seaborn-whitegrid')
# Out:
# 2023-04-21 18:14:44.234380: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /tmp/ipykernel_1983620/1293145838.py:10: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
import os
import glob
from pymongo import MongoClient
import pandas as pd

database = "vnw_job"
col = "items"

mongo = MongoClient("mongodb://10.122.6.17:27017")
df_meta = pd.DataFrame(list(mongo[database][col].find()))
df_meta['jobTitle'] = df_meta.categoricalProps.apply(lambda x: x["jobTitle"][0])
df_meta['skills'] = df_meta.categoricalProps.apply(lambda x: ','.join(x["skills"]))
df_meta['industries'] = df_meta.categoricalProps.apply(lambda x: ','.join(x["industries"]))
df_meta['locations'] = df_meta.categoricalProps.apply(lambda x: ','.join(x["locations"]))
df_meta['jobLevel'] = df_meta.categoricalProps.apply(lambda x: ','.join(x["jobLevel"]))
df_meta['availableDate'] = df_meta.dateProps.apply(lambda x: x["availableDate"])
df = pd.read_parquet(glob.glob("/home/spark/ylv/data/navidata/*.parquet"))

# %%
ratings = df.merge(df_meta, left_on="targetEntityId", right_on="_id", how="left")

# %%
ratings = ratings.fillna('UNK')

# %%
from sklearn.model_selection import train_test_split

# %%
rating_1st, rating_2nd = train_test_split(ratings, test_size=0.2)

# %%
rating_1st.shape, rating_2nd.shape
# Out:
# ((8032554, 13), (2008139, 13))

# %%
# %%time

movies = tf.data.Dataset.from_tensor_slices({
    "job_id": df_meta._id.values.tolist(),
    "category": df_meta.industries.values.tolist(),
    "location": df_meta.locations.values.tolist(),
    "level": df_meta.jobLevel.values.tolist(),
    "job_title": df_meta.jobTitle.values.tolist(),
    "skill_text": df_meta.skills.values.tolist()
})

tensor_slices = {
    "user_id": rating_1st.entityId.values.tolist(),
    "job_id": rating_1st.targetEntityId.values.tolist(),
    "location": rating_1st.locations.values.tolist(),
    "category": rating_1st.industries.values.tolist(),
    "level": rating_1st.jobLevel.values.tolist(),
    "job_title": rating_1st.jobTitle.values.tolist(),
    "skill_text": rating_1st.skills.values.tolist()
}
# Out:
# 2023-04-21 18:15:44.495905: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-21 18:15:44.517191: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-21 18:15:44.517337: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-21 18:15:44.517705: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-21 18:15:44.518429: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-21 18:15:44.518564: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-21 18:15:44.518688: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-21 18:15:44.930047: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-21 18:15:44.930198: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-21 18:15:44.930311: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-21 18:15:44.930411: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6380 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2070, pci bus id: 0000:02:00.0, compute capability: 7.5
# CPU times: user 788 ms, sys: 343 ms, total: 1.13 s
# Wall time: 1.15 s

# %%
# %%time

ds_rating_1st = tf.data.Dataset.from_tensor_slices(tensor_slices)
# Out:
# CPU times: user 53.1 s, sys: 1.89 s, total: 55 s
# Wall time: 55 s

# %%
# %%time

from functools import reduce

unique_job_titles = np.unique(df_meta.jobTitle.values.tolist())
unique_job_ids = np.unique(df_meta._id.values.tolist())
unique_user_ids = np.unique(rating_1st.entityId.values.tolist())
unique_locations = np.unique(reduce(lambda x, y: x + "," + y, df_meta.locations.values.tolist()).split(","))
unique_skills = np.unique(reduce(lambda x, y: x + "," + y, df_meta.skills.values.tolist()).split(","))
# job_title_vocabs = np.unique(reduce(lambda x, y: x + y, df_meta.title.str.split(" ").tolist()))
unique_category = np.unique(reduce(lambda x, y: x + "," + y, df_meta.industries.values.tolist()).split(","))
# Out:
# CPU times: user 6.74 s, sys: 1.21 s, total: 7.95 s
# Wall time: 7.95 s

# %%
# %%time

unique_levels = np.unique(reduce(lambda x, y: x + "," + y, df_meta.jobLevel.values.tolist()).split(","))
# Out:
# CPU times: user 136 ms, sys: 613 µs, total: 136 ms
# Wall time: 138 ms

# %%
class UserModel(tf.keras.Model):

  def __init__(self):
    super().__init__()

    self.user_embedding = tf.keras.Sequential([
        tf.keras.layers.StringLookup(
            vocabulary=unique_user_ids, mask_token=None, name='user_stringlookup_layer'),
        tf.keras.layers.Embedding(len(unique_user_ids) + 1, 32, name='user_embedding_layer'),
    ], name='user_embedding_model')

  def call(self, inputs):
    # Take the input dictionary, pass it through each input layer,
    # and concatenate the result.
    return tf.concat([
        self.user_embedding(inputs["user_id"])
    ], axis=1)

# %%
class QueryModel(tf.keras.Model):
  """Model for encoding user queries."""

  def __init__(self, layer_sizes):
    """Model for encoding user queries.

    Args:
      layer_sizes:
        A list of integers where the i-th entry represents the number of units
        the i-th layer contains.
    """
    super().__init__()

    # We first use the user model for generating embeddings.
    self.embedding_model = UserModel()

    # Then construct the layers.
    self.dense_layers = tf.keras.Sequential()

    # Use the ReLU activation for all but the last layer.
    for layer_size in layer_sizes[:-1]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size, activation="relu"))

    # No activation for the last layer.
    for layer_size in layer_sizes[-1:]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size))

  def call(self, inputs):
    feature_embedding = self.embedding_model(inputs)
    print(feature_embedding)
    return self.dense_layers(feature_embedding)

# %%
def tokenization(t):
    return tf.strings.split(t, ',')

def tokenization_1(t):
    return tf.strings.split(t, ' ')


class MovieModel(tf.keras.Model):

  def __init__(self):
    super().__init__()

    max_tokens = 10_000

    self.job_id_embedding = tf.keras.Sequential([
      tf.keras.layers.StringLookup(
          vocabulary=unique_job_ids,mask_token=None),
      tf.keras.layers.Embedding(len(unique_job_ids) + 1, 32)
    ])
    self.location_embedding = tf.keras.Sequential([
      tf.keras.layers.TextVectorization(
          max_tokens=100,
          standardize=None,
          split=tokenization,
          vocabulary=unique_locations,
          pad_to_max_tokens=True
      ),
      tf.keras.layers.Embedding(len(unique_locations) + 1, 32),
      tf.keras.layers.GlobalAvgPool1D()
    ])
    self.level_embedding = tf.keras.Sequential([
      tf.keras.layers.TextVectorization(
          max_tokens=100,
          standardize=None,
          split=tokenization,
          vocabulary=unique_levels,
          pad_to_max_tokens=True
      ),
      tf.keras.layers.Embedding(len(unique_levels) + 1, 32),
      tf.keras.layers.GlobalAvgPool1D()
    ])
    self.category_embedding = tf.keras.Sequential([
      tf.keras.layers.TextVectorization(
          max_tokens=100,
          standardize=None,
          split=tokenization,
          vocabulary=unique_category,
          pad_to_max_tokens=True
      ),
      tf.keras.layers.Embedding(len(unique_category) + 1, 64),
      tf.keras.layers.GlobalAvgPool1D()
    ])
#     self.skill_embedding = tf.keras.Sequential([
#       tf.keras.layers.TextVectorization(
#           max_tokens=100,
#           standardize=None,
#           split=tokenization,
#           vocabulary=unique_skills,
#           pad_to_max_tokens=True
#       ),
#       tf.keras.layers.Embedding(len(unique_skills) + 1, 32),
#       tf.keras.layers.GlobalAvgPool1D()
#     ])

  def call(self, features):
    return tf.concat([
        self.job_id_embedding(features["job_id"]),
        self.category_embedding(features["category"]),
        self.location_embedding(features["location"]),
        self.level_embedding(features["level"]),
#         self.skill_embedding(features["skill_text"])
    ], axis=1)

# %%
class CandidateModel(tf.keras.Model):
  """Model for encoding movies."""

  def __init__(self, layer_sizes):
    """Model for encoding movies.

    Args:
      layer_sizes:
        A list of integers where the i-th entry represents the number of units
        the i-th layer contains.
    """
    super().__init__()

    self.embedding_model = MovieModel()

    # Then construct the layers.
    self.dense_layers = tf.keras.Sequential()

    # Use the ReLU activation for all but the last layer.
    for layer_size in layer_sizes[:-1]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size, activation="relu"))

    # No activation for the last layer.
    for layer_size in layer_sizes[-1:]:
      self.dense_layers.add(tf.keras.layers.Dense(layer_size))

  def call(self, inputs):
    feature_embedding = self.embedding_model(inputs)
    return self.dense_layers(feature_embedding)

# %%
class MovielensModel(tfrs.models.Model):

  def __init__(self, layer_sizes):
    super().__init__()
    self.query_model = QueryModel(layer_sizes)
    self.candidate_model = CandidateModel(layer_sizes)
    self.task = tfrs.tasks.Retrieval(
        metrics=tfrs.metrics.FactorizedTopK(
            candidates=movies.batch(128).map(self.candidate_model),
        ),
    )

  def compute_loss(self, features, training=False):
    # We only pass the user id and timestamp features into the query model. This
    # is to ensure that the training inputs would have the same keys as the
    # query inputs. Otherwise the discrepancy in input structure would cause an
    # error when loading the query model after saving it.
    query_embeddings = self.query_model({
        "user_id": features["user_id"]
    })
    movie_embeddings = self.candidate_model({
        "job_id": features["job_id"],
        "job_title": features["job_title"],
        "category": features["category"],
        "location": features["location"],
        "skill_text": features["skill_text"],
        "level": features["level"],
    })

    return self.task(
        query_embeddings, movie_embeddings, compute_metrics=not training)

# %%
cached_train_1st = ds_rating_1st.batch(4096)

# %%
# %%time

num_epochs = 50

model = MovielensModel([128, 64, 32])
model.compile(optimizer=tf.keras.optimizers.Adagrad(0.1))

one_layer_history = model.fit(
    cached_train_1st,
    validation_freq=5,
    epochs=num_epochs,
    verbose=0)
# Out:
# Tensor("query_model/user_model/concat/concat:0", shape=(None, 32), dtype=float32)
# Tensor("query_model/user_model/concat/concat:0", shape=(None, 32), dtype=float32)
# 2023-04-21 18:16:57.468444: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7f8fb7186210 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-04-21 18:16:57.468474: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce RTX 2070, Compute Capability 7.5
# 2023-04-21 18:16:57.470777: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-04-21 18:16:57.510865: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:57.535611: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-04-21 18:16:57.571319: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:57.705982: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:57.877619: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.058083: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.132013: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.204996: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.278814: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.350246: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.433226: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.507623: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.581558: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.663510: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.737190: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.810122: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.882339: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:58.964391: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.036987: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.111807: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.203933: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.278590: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.353291: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.437304: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.511690: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.590849: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.664326: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.737135: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.822719: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.904595: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:16:59.980250: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:00.059840: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:00.151889: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:00.235528: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:00.306996: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:00.384178: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:00.455950: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:00.537936: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:00.619075: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:00.691407: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:00.765509: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:00.849606: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:00.932545: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.005720: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.087730: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.181347: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.254926: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.338356: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.420111: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.501116: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.579157: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.652931: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.729694: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.802445: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.879349: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:01.958104: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.037253: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.122090: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.204825: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.276106: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.347962: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.434774: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.506972: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.583898: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.655097: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.727470: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.808167: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.898351: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:02.969951: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:03.047363: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:03.119597: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:03.202231: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:03.283595: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:03.363428: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:03.436204: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:03.509447: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:03.594850: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:03.681360: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:03.760604: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:03.836216: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:03.927619: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.005648: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.099796: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.181459: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.259570: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.337665: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.419950: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.491579: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.568756: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.640298: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.717171: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.793969: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.865164: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:04.955186: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.026621: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.103571: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.182550: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.260636: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.332537: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.409836: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.487720: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.565817: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.654187: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.739757: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.834135: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.911773: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:05.988193: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:06.074515: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:06.154175: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:06.252426: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:06.333830: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:06.431766: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:06.505835: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:06.591711: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:06.678971: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:06.774398: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:06.854524: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:06.933844: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:07.005912: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:07.085218: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:07.158872: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:07.236545: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:07.309793: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:07.398632: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:07.519051: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:07.605205: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:07.691903: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:07.794988: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# ...
# 2023-04-21 18:17:18.427243: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:18.925055: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:19.822819: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:19.993661: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:20.349332: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:20.545195: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:20.839100: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:20.958870: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:21.277557: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:21.356285: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:21.494917: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:21.598234: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:21.828603: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:22.140942: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:22.391135: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:22.603709: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:22.835080: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:22.937249: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:23.205266: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:23.286174: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:23.414116: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:23.670107: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:23.767586: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:24.015985: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:24.187056: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:24.274386: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:24.677241: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:24.809828: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:25.110256: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:25.321619: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:25.599267: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:25.890842: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:26.490143: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:27.286551: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:27.443074: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:27.901777: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:29.822067: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:31.635294: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:31.894675: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:32.135828: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:32.208547: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:32.280145: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# 2023-04-21 18:17:32.349291: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:115] *** WARNING *** You are using ptxas 10.1.243, which is older than 11.1. ptxas before 11.1 is known to miscompile XLA code, leading to incorrect results or invalid-address errors.
#
# You may not need to update to CUDA 11.1; cherry-picking the ptxas binary is often sufficient.
# CPU times: user 35min 56s, sys: 1min 5s, total: 37min 1s
# Wall time: 14min 36s

# %%
index = tfrs.layers.factorized_top_k.BruteForce(model.query_model, k=10)
index.index_from_dataset(
    movies.batch(500).map(lambda x: (x["job_id"], model.candidate_model(x))))
# Out:
# WARNING:tensorflow:From /home/spark/miniconda3/envs/recommend/lib/python3.9/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
import random

u = random.choice(unique_user_ids)
print("========================HISTORY==============================")
rating_1st[rating_1st.entityId==u][["targetEntityId","jobTitle", "industries", "jobLevel", "locations", "skills"]]
# score, pred = index({"user_id": np.array(["5749316"])})
# list(map(lambda x: x.decode('ascii'), pred.numpy()[0]))
# df_meta[df_meta._id.isin(list(map(lambda x: x.decode('ascii'), pred.numpy()[0])))][["jobTitle", "industries", "locations", "jobLevel", "skills"]]
# Out:
# ========================HISTORY==============================
#         targetEntityId jobTitle industries jobLevel locations skills
# 4634827        1617861      UNK        UNK      UNK       UNK    UNK

# %%
score, pred = index({"user_id": np.array(["14.186.104.233, 10.122.10.10"])})
# list(map(lambda x: x.decode('ascii'), pred.numpy()[0]))
df_meta[df_meta._id.isin(list(map(lambda x: x.decode('ascii'), pred.numpy()[0])))][["jobTitle", "industries", "locations", "jobLevel", "skills"]]
# Out:
# tf.Tensor(
# [[ 0.25018522 -0.04359851  0.38761485 -0.22241382 -0.18109947  0.26559716
#   -0.25351247  0.34905553 -0.0225444  -0.23030001  0.01781677 -0.00725579
#   -0.08491569 -0.673024   -0.24497876  0.0909945   0.30467156  0.08764698
#   -0.11209524 -0.09641353 -0.08389925 -0.26434812  0.33045956 -0.12258724
#   -0.36470428 -0.18804297 -0.34601757  0.02455912  0.1951107   0.33963367
#   -0.04576489  0.23378743]], shape=(1, 32), dtype=float32)
#                                                 jobTitle  \
# 6978                                   account associate
# 8166   tro ly du an project assistant muc luong tu 9 ...
# 9233                         nhan vien phong sales admin
# 9452   nhan vien hanh chinh va xu ly ho so ha noi nha...
# 9624               can bo ngan hang chi nhanh thanh xuan
# 9690       admin officer nhan vien hanh chinh bo phan pt
# 10972                                        sales admin
# 11892                      chuyen vien ho tro kinh doanh
# 12484                      ho tro phong kinh doanh du an
# 13191    ky su phat trien ung dung application developer
#
#                                               industries           locations  \
# 6978                    Customer Service,Marketing,Sales              Ha Noi
# 8166   Administrative/Clerical,Civil/Construction,Pla...              Ha Noi
# 9233             Administrative/Clerical,Marketing,Sales              Ha Noi
# 9452                 Customer Service,Education/Training  Ho Chi Minh,Ha Noi
# 9624                          Banking,Finance/Investment              Ha Noi
# 9690   Administrative/Clerical,Customer Service,Entry...              Ha Noi
# 10972  Customer Service,Export-Import,Production/Process              Ha Noi
# 11892  Administrative/Clerical,Legal/Contracts,Financ...              Ha Noi
# 12484       Customer Service,Marketing,Planning/Projects              Ha Noi
# 13191  Production/Process,IT - Software,Planning/Proj...              Ha Noi
#
#                         jobLevel  \
# 6978         Fresher/Entry level
# 8166   Experienced (non-manager)
# 9233   Experienced (non-manager)
# 9452         Fresher/Entry level
# 9624   Experienced (non-manager)
# 9690         Fresher/Entry level
# 10972  Experienced (non-manager)
# 11892  Experienced (non-manager)
# 12484  Experienced (non-manager)
# 13191  Experienced (non-manager)
#
#                                                   skills
# 6978   tiep can khach hang,gioi thieu san pham,tu van...
# 8166   ho so dau thau,theo doi bao cao,thanh quyet to...
# 9233   system admin,phan tich,english skill,administr...
# 9452                               communication,english
# 9624   teller operations,credit,credit operations,sal...
# 9690   admin,administrative management,entry level,va...
# 10972  sales admin,customer service,cham soc khach ha...
# 11892  luat doanh nghiep,quan ly ho so,english,phan t...
# 12484  giai phap cong nghe,lap ke hoach du an,tieng a...
# 13191  english,object oriented,ms sql server,oracle,p...

# %%
"6814502" in unique_user_ids, rating_2nd.shape
# Out:
# (True, (2008139, 13))

# %%
user_ids_2nd = np.unique(rating_2nd.entityId.values.tolist())

# %%
new_unique_userids = set(user_ids_2nd) - set(unique_user_ids)
len(new_unique_userids)
# Out:
# 49928

# %%
new_unique_userids
# Out:
# {'27.75.108.13, 10.122.10.10',
#  '116.105.170.32, 10.122.10.10',
#  '14.185.171.90, 10.122.10.10',
#  '14.242.153.15, 10.122.10.10',
#  '3301573',
#  '14.241.199.101, 10.122.10.10',
#  '123.19.228.2, 10.122.10.10',
#  '114.119.143.177, 10.122.10.10',
#  '14.237.160.185, 10.122.10.10',
#  '171.253.4.188, 10.122.10.10',
#  '113.187.245.75, 10.122.10.10',
#  '27.70.247.211, 10.122.10.10',
#  '6867486',
#  '14.191.57.185, 10.122.10.10',
#  '117.5.141.207, 10.122.10.10',
#  '116.96.120.80, 10.122.10.10',
#  '165.225.230.112, 10.122.10.10',
#  '14.167.171.135, 10.122.10.10',
#  '116.109.185.198, 10.122.10.10',
#  '171.251.234.53, 10.122.10.10',
#  '171.247.79.73, 10.122.10.10',
#  '1.55.42.235, 10.122.10.10',
#  '113.163.72.143, 10.122.10.10',
#  '7149361',
#  '14.187.236.243, 10.122.10.10',
#  '1.52.99.184, 10.122.10.10',
#  '123.24.189.215, 10.122.10.10',
#  '116.110.243.143, 10.122.10.10',
#  '123.20.253.213, 10.122.10.10',
#  '113.160.185.101, 10.122.10.10',
#  '14.191.101.230, 10.122.10.10',
#  '14.244.191.12, 10.122.10.10',
#  '171.236.135.223, 10.122.10.10',
#  '58.187.75.143, 10.122.10.10',
#  '27.118.21.252, 10.122.10.10',
#  '91.204.136.165, 10.122.10.10',
#  '27.78.7.242, 10.122.10.10',
#  '123.26.219.222, 10.122.10.10',
#  '123.19.255.151, 10.122.10.10',
#  '42.112.107.230, 10.122.10.10',
#  '210.245.104.98, 10.122.10.10',
#  '222.253.169.27, 10.122.10.10',
#  '42.115.200.107, 10.122.10.10',
#  '118.69.6.105, 10.122.10.10',
#  '183.80.106.62, 10.122.10.10',
#  '171.241.229.190, 10.122.10.10',
#  '27.78.6.242, 10.122.10.10',
#  '171.234.13.227, 10.122.10.10',
#  '10.1.6.78, 222.252.14.118, 10.122.10.10',
#  ...}

# %%
score, pred = index({"user_id": np.array(["6937452"])})
list(map(lambda x: x.decode('ascii'), pred.numpy()[0]))
df_meta[df_meta._id.isin(list(map(lambda x: x.decode('ascii'), pred.numpy()[0])))][["jobTitle", "industries", "locations", "jobLevel", "skills"]]
# Out:
# tf.Tensor(
# [[ 0.00507442  0.5163779  -0.5457415   0.5571508  -0.15455909  0.11636562
#    0.00845364  0.21496324  0.01792824  0.14123039  0.39737588  0.19248845
#   -0.45298576 -0.00458293  0.4227991  -0.4689922   0.13474075  0.0117634
#   -0.35706902  0.05359838  0.2914499  -0.08387545 -0.38715577  0.4530252
#   -0.46546844  0.4231716   0.4784828   0.46473625 -0.10187411  0.52279186
#   -0.36248457 -0.12246305]], shape=(1, 32), dtype=float32)
#                                                jobTitle  \
# 172                                 pho phong tai chinh
# 681       finance assistant manager pho phong tai chinh
# 1176                     assistant financial controller
# 1497                     finance and accounting manager
# 1500                                     ke toan truong
# 2328  sage 100 contractor consultant accountant book...
# 4137          assistant manager financial reporting tax
# 4936                               financial controller
# 5326    chief accountant manufacturing garment industry
# 6440                                   chief accountant
#
#                                              industries    locations  \
# 172              Accounting,Auditing,Finance/Investment  Ho Chi Minh
# 681               Accounting,Banking,Finance/Investment  Ho Chi Minh
# 1176              Accounting,Finance/Investment,Fintech  Ho Chi Minh
# 1497             Accounting,Auditing,Finance/Investment  Ho Chi Minh
# 1500             Accounting,Auditing,Finance/Investment  Ho Chi Minh
# 2328           Accounting,Civil/Construction,Consulting  Ho Chi Minh
# 4137  Accounting,Administrative/Clerical,Finance/Inv...  Ho Chi Minh
# 4936             Accounting,Auditing,Finance/Investment  Ho Chi Minh
# 5326             Accounting,Auditing,Finance/Investment  Ho Chi Minh
# 6440          Accounting,Real Estate,Finance/Investment  Ho Chi Minh
#
#                        jobLevel  \
# 172                     Manager
# 681   Experienced (non-manager)
# 1176                    Manager
# 1497                    Manager
# 1500                    Manager
# 2328  Experienced (non-manager)
# 4137                    Manager
# 4936                    Manager
# 5326                    Manager
# 6440                    Manager
#
#                                                  skills
# 172   tai chinh ngan hang,thanh toan quoc te,phan me...
# 681   finance,finance analysis,accounting,management...
# 1176  ke toan,tai chinh,financial report,financial c...
# 1497  financial management,finance management,accoun...
# 1500  ke toan quan ly,lap chung tu ke toan,ke toan s...
# 2328  english,sage 100 erp,accounting,finance,constr...
# 4137  analyzing statistics,financial databases,finan...
# 4936  finance controling,cpa,accounting,finance,kiem...
# 5326  chief accountant certificate,manufacturing,gar...
# 6440  chief accountant certificate,auditing,financin...

# %%
embedding_weights_base = model.query_model.get_layer("user_model").get_layer("user_embedding_model").get_layer('user_embedding_layer').get_weights()[0]

# %%
new_unique_users = np.unique(list(new_unique_userids))

# %%
# Generate the updated embedding matrix
updated_embedding = tf.keras.utils.warmstart_embedding_matrix(
    base_vocabulary=unique_user_ids,
    new_vocabulary=new_unique_users,
    base_embeddings=embedding_weights_base,
    new_embeddings_initializer="uniform",
)

# Update the model variable
updated_embedding_variable = tf.Variable(updated_embedding)

# %%
class UpdatedUserModel(tf.keras.Model):

  def __init__(self, new_user, embeded_user):
    super().__init__()
    user_embedding_layer_new = tf.keras.layers.Embedding(
        len(new_user), 32
    )
    user_embedding_layer_new.build(input_shape=[None])
    user_embedding_layer_new.embeddings.assign(updated_embedding)
    self.user_embedding = tf.keras.Sequential([
        tf.keras.layers.StringLookup(
            vocabulary=unique_user_ids, mask_token=None, name='user_stringlookup_layer'),
        tf.keras.layers.Embedding(len(unique_user_ids) + 1, 32, name='user_embedding_layer'),
    ], name='user_embedding_model')

  def call(self, inputs):
    # Take the input dictionary, pass it through each input layer,
    # and concatenate the result.
    return tf.concat([
        self.user_embedding(inputs["user_id"])
    ], axis=1)

# %%
embedding_dimension = 32

user_embedding_layer_new = tf.keras.layers.Embedding(
    len(new_unique_users), embedding_dimension
)

user_embedding_layer_new.build(input_shape=[None])
user_embedding_layer_new.embeddings.assign(updated_embedding)
user_model = tf.keras.Sequential([
    tf.keras.layers.StringLookup(vocabulary=new_unique_users, mask_token=None),
    user_embedding_layer_new
])

# %%
model.query_model.embedding_model.user_embedding = tf.keras.Sequential([
    tf.keras.layers.StringLookup(vocabulary=new_unique_users, mask_token=None),
    user_embedding_layer_new
])

# %%
#6937452
model.query_model({"user_id": np.array(["6937452"])}) == model.query_model({"user_id": np.array(["2989560"])})
# Out:
# tf.Tensor(
# [[-0.0234861   0.01408077 -0.00506867 -0.01083786 -0.03551828 -0.03978927
#   -0.01406171  0.01756055  0.00213837  0.03844894 -0.04808125  0.02579955
#    0.02994614 -0.04239151 -0.00475564  0.01889436  0.01769005  0.00497582
#    0.04829449 -0.03534007 -0.02135521 -0.01391004  0.02308876  0.00114753
#   -0.00017706  0.01722101 -0.0351498   0.02637174 -0.00686129 -0.01457911
#   -0.0268388  -0.00599152]], shape=(1, 32), dtype=float32)
# tf.Tensor(
# [[-0.0234861   0.01408077 -0.00506867 -0.01083786 -0.03551828 -0.03978927
#   -0.01406171  0.01756055  0.00213837  0.03844894 -0.04808125  0.02579955
#    0.02994614 -0.04239151 -0.00475564  0.01889436  0.01769005  0.00497582
#    0.04829449 -0.03534007 -0.02135521 -0.01391004  0.02308876  0.00114753
#   -0.00017706  0.01722101 -0.0351498   0.02637174 -0.00686129 -0.01457911
#   -0.0268388  -0.00599152]], shape=(1, 32), dtype=float32)
# <tf.Tensor: shape=(1, 32), dtype=bool, numpy=
# array([[ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True]])>

# %%
# %%time

tensor_slices_2nd = {
    "user_id": rating_2nd.entityId.values.tolist(),
    "job_id": rating_2nd.targetEntityId.values.tolist(),
    "location": rating_2nd.locations.values.tolist(),
    "category": rating_2nd.industries.values.tolist(),
    "level": rating_2nd.jobLevel.values.tolist(),
    "job_title": rating_2nd.jobTitle.values.tolist(),
    "skill_text": rating_2nd.skills.values.tolist()
}

ds_rating_2nd = tf.data.Dataset.from_tensor_slices(tensor_slices_2nd)
cached_train_2nd = ds_rating_2nd.batch(4096)
# Out:
# CPU times: user 13.5 s, sys: 376 ms, total: 13.8 s
# Wall time: 13.8 s

# %%
ds = ds_rating_1st.concatenate(ds_rating_2nd)

# %%
len(ds)
# Out:
# 10040693

# %%
# %%time
num_epochs = 50

model = MovielensModel([128, 64, 32])
model.compile(optimizer=tf.keras.optimizers.Adagrad(0.1))

one_layer_history = model.fit(
    ds,
    validation_freq=5,
    epochs=num_epochs,
    verbose=0)
# Out:
# Tensor("query_model_3/user_model_3/concat/concat:0", shape=(32,), dtype=float32)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/miniconda3/envs/recommend/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/miniconda3/envs/recommend/lib/python3.9/site-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ~/miniconda3/envs/recommend/lib/python3.9/site-packages/tensorflow_recommenders/models/base.py in train_step(self, inputs)
#      66
#      67     with tf.GradientTape() as tape:
# ---> 68       loss = self.compute_loss(inputs, training=True)
#      69
#      70       # Handle regularization losses as well.
#
# /tmp/ipykernel_1972309/95081500.py in compute_loss(self, features, training)
#      16     # query inputs. Otherwise the discrepancy in input structure would cause an
#      17     # error when loading the query model after saving it.
# ---> 18     query_embeddings = self.query_model({
#      19         "user_id": features["user_id"]
#      20     })
#
# /tmp/__autograph_generated_file1p27ljn2.py in tf__call(self, inputs)
#      12                 try:
#      13                     do_return = True
# ---> 14                     retval_ = ag__.converted_call(ag__.ld(self).dense_layers, (ag__.ld(feature_embedding),), None, fscope)
#      15                 except:
#      16                     do_return = False
#
# ValueError: in user code:
#
#     File "/home/spark/miniconda3/envs/recommend/lib/python3.9/site-packages/keras/engine/training.py", line 1249, in train_function  *
#         return step_function(self, iterator)
#     File "/home/spark/miniconda3/envs/recommend/lib/python3.9/site-packages/keras/engine/training.py", line 1233, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/home/spark/miniconda3/envs/recommend/lib/python3.9/site-packages/keras/engine/training.py", line 1222, in run_step  **
#         outputs = model.train_step(data)
#     File "/home/spark/miniconda3/envs/recommend/lib/python3.9/site-packages/tensorflow_recommenders/models/base.py", line 68, in train_step
#         loss = self.compute_loss(inputs, training=True)
#     File "/tmp/ipykernel_1972309/95081500.py", line 18, in compute_loss
#         query_embeddings = self.query_model({
#     File "/home/spark/miniconda3/envs/recommend/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/tmp/__autograph_generated_file1p27ljn2.py", line 14, in tf__call
#         retval_ = ag__.converted_call(ag__.ld(self).dense_layers, (ag__.ld(feature_embedding),), None, fscope)
#
#     ValueError: Exception encountered when calling layer 'query_model_3' (type QueryModel).
#
#     in user code:
#
#         File "/tmp/ipykernel_1972309/2011177071.py", line 31, in call  *
#             return self.dense_layers(feature_embedding)
#         File "/home/spark/miniconda3/envs/recommend/lib/python3.9/site-packages/keras/utils/traceback_utils.py", line 70, in error_handler  **
#             raise e.with_traceback(filtered_tb) from None
#         File "/home/spark/miniconda3/envs/recommend/lib/python3.9/site-packages/keras/engine/input_spec.py", line 250, in assert_input_compatibility
#             raise ValueError(
#
#         ValueError: Exception encountered when calling layer 'sequential_24' (type Sequential).
#
#         Input 0 of layer "dense_18" is incompatible with the layer: expected min_ndim=2, found ndim=1. Full shape received: (32,)
#
#         Call arguments received by layer 'sequential_24' (type Sequential):
#           • inputs=tf.Tensor(shape=(32,), dtype=float32)
#           • training=None
#           • mask=None
#
#
#     Call arguments received by layer 'query_model_3' (type QueryModel):
#       • inputs={'user_id': 'tf.Tensor(shape=(), dtype=string)'}

# %%
index2nd = tfrs.layers.factorized_top_k.BruteForce(model.query_model, k=10)
index2nd.index_from_dataset(
    movies.batch(500).map(lambda x: (x["job_id"], model.candidate_model(x))))

# %%
import random

u_n = random.choice(unique_user_ids)
print("========================HISTORY==============================")
rating_2nd[rating_2nd.entityId==u_n][["targetEntityId","jobTitle", "industries", "jobLevel", "locations", "skills"]]
# score, pred = index({"user_id": np.array(["5749316"])})
# list(map(lambda x: x.decode('ascii'), pred.numpy()[0]))
# df_meta[df_meta._id.isin(list(map(lambda x: x.decode('ascii'), pred.numpy()[0])))][["jobTitle", "industries", "locations", "jobLevel", "skills"]]
# Out:
# ========================HISTORY==============================
#         targetEntityId                                   jobTitle  \
# 3203100        1627729  can bo phu trach ho so thau nghi t7 cn nu
#
#                                                 industries  \
# 3203100  Civil/Construction,Legal/Contracts,Planning/Pr...
#
#                           jobLevel locations  \
# 3203100  Experienced (non-manager)    Ha Noi
#
#                                                     skills
# 3203100  ho so du thau,xay dung hop dong,chuan bi ho so...

# %%
score, pred = index2nd({"user_id": np.array([u_n])})
# list(map(lambda x: x.decode('ascii'), pred.numpy()[0]))
df_meta[df_meta._id.isin(list(map(lambda x: x.decode('ascii'), pred.numpy()[0])))][["jobTitle", "industries", "locations", "jobLevel", "skills"]]
# Out:
# tf.Tensor(
# [[-0.0234861   0.01408077 -0.00506867 -0.01083786 -0.03551828 -0.03978927
#   -0.01406171  0.01756055  0.00213837  0.03844894 -0.04808125  0.02579955
#    0.02994614 -0.04239151 -0.00475564  0.01889436  0.01769005  0.00497582
#    0.04829449 -0.03534007 -0.02135521 -0.01391004  0.02308876  0.00114753
#   -0.00017706  0.01722101 -0.0351498   0.02637174 -0.00686129 -0.01457911
#   -0.0268388  -0.00599152]], shape=(1, 32), dtype=float32)
#                                                 jobTitle  \
# 3818       kien truc su thiet ke 3d lumion hue va da lat
# 6372                            service engineer can tho
# 7913                                   software engineer
# 8303               truong nhom thu hoi no qua dien thoai
# 10689  chuyen vien tu van tai chinh kenh lien doanh n...
# 10764                                ky su lap trinh c c
# 10847                  chuyen vien xu ly no nam duoi 32t
# 11006                                            luat su
# 13104                                      php developer
# 13324                                            officer
#
#                                               industries  \
# 3818   Architecture/Interior Design,Civil/Constructio...
# 6372       Electrical/Electronics,Mechanical,Maintenance
# 7913              Sales,Banking,IT - Hardware/Networking
# 8303                     Legal/Contracts,Banking,Fintech
# 10689              Consulting,Banking,Finance/Investment
# 10764  IT - Software,Telecommunications,IT - Hardware...
# 10847         Legal/Contracts,Banking,Finance/Investment
# 11006  Administrative/Clerical,Consulting,Legal/Contr...
# 13104  IT - Software,IT - Hardware/Networking,Plannin...
# 13324                                              Other
#
#                           locations                   jobLevel  \
# 3818        Lam Dong,Thua Thien Hue         Director and above
# 6372                        Can Tho  Experienced (non-manager)
# 7913                    Ho Chi Minh  Experienced (non-manager)
# 8303                    Ho Chi Minh  Experienced (non-manager)
# 10689  Binh Dinh,Khanh Hoa,Lam Dong  Experienced (non-manager)
# 10764                        Ha Noi  Experienced (non-manager)
# 10847        Binh Phuoc,Ho Chi Minh  Experienced (non-manager)
# 11006                       Da Nang  Experienced (non-manager)
# 13104                   Ho Chi Minh  Experienced (non-manager)
# 13324                         Other  Experienced (non-manager)
#
#                                                   skills
# 3818   dien hoa 3d,lumion,phoi canh 3d noi that,3ds m...
# 6372   english,repairs mechanical,operating system,tr...
# 7913                   english,python,selenium webdriver
# 8303                       thu hoi no phap ly,thu hoi no
# 10689  bao hiem,ngan hang,tu van tai chinh,bat dong s...
# 10764  c,linux,software development,dien tu vien thon...
# 10847   xu ly no xau,tin chap,luat,thu hoi no,quan li no
# 11006  legal,tu van luat,ho so phap ly,soan thao hop ...
# 13104     php,javascript,postgresql,my sql,css framework
# 13324                                               test

# %%
score, pred = index({"user_id": np.array([u_n])})
# list(map(lambda x: x.decode('ascii'), pred.numpy()[0]))
df_meta[df_meta._id.isin(list(map(lambda x: x.decode('ascii'), pred.numpy()[0])))][["jobTitle", "industries", "locations", "jobLevel", "skills"]]
# Out:
# tf.Tensor(
# [[-0.04995194  0.02714846 -0.01379492  0.0141131  -0.04381491  0.03947688
#    0.02812408 -0.03205021 -0.00940702 -0.01702154 -0.00846279 -0.03094795
#    0.02805856  0.02528908 -0.02155509 -0.00801569 -0.03114945  0.02834776
#   -0.03922702 -0.02906051 -0.02550958  0.00732602  0.01184895  0.00498318
#    0.021412   -0.02221696  0.02597881 -0.02779089 -0.03435098 -0.02546695
#    0.04897121 -0.00072067]], shape=(1, 32), dtype=float32)
#                                             jobTitle  \
# 3818   kien truc su thiet ke 3d lumion hue va da lat
# 6265                                          qc ct1
# 7090   giang vien cong nghe thong tin fpl tay nguyen
# 9243                             lead java developer
# 9699    nhan vien van hanh nha may dien gio mat troi
# 10023               hcm 3000 4300 lead java engineer
# 10764                            ky su lap trinh c c
# 12433                            fresher qa engineer
# 13104                                  php developer
# 13324                                        officer
#
#                                               industries  \
# 3818   Architecture/Interior Design,Civil/Constructio...
# 6265                                       IT - Software
# 7090                    Education/Training,IT - Software
# 9243                                       IT - Software
# 9699       Electrical/Electronics,Mechanical,Maintenance
# 10023             IT - Software,IT - Hardware/Networking
# 10764  IT - Software,Telecommunications,IT - Hardware...
# 12433             IT - Software,IT - Hardware/Networking
# 13104  IT - Software,IT - Hardware/Networking,Plannin...
# 13324                                              Other
#
#                           locations                   jobLevel  \
# 3818        Lam Dong,Thua Thien Hue         Director and above
# 6265                    Ho Chi Minh  Experienced (non-manager)
# 7090                        Dak Lak  Experienced (non-manager)
# 9243                    Ho Chi Minh                    Manager
# 9699   Soc Trang,Binh Dinh,Tay Ninh        Fresher/Entry level
# 10023                   Ho Chi Minh  Experienced (non-manager)
# 10764                        Ha Noi  Experienced (non-manager)
# 12433                   Ho Chi Minh  Experienced (non-manager)
# 13104                   Ho Chi Minh  Experienced (non-manager)
# 13324                         Other  Experienced (non-manager)
#
#                                                   skills
# 3818   dien hoa 3d,lumion,phoi canh 3d noi that,3ds m...
# 6265                                                  qc
# 7090   giao duc,cong nghe thong tin phan mem,ngon ngu...
# 9243   java,spring framework,react,troubleshooting an...
# 9699   tu dong hoa,dien mat troi,dien gio,du an nang ...
# 10023           java,reactjs,microservice,domain banking
# 10764  c,linux,software development,dien tu vien thon...
# 12433  php,java,c#,software development,lap trinh he ...
# 13104     php,javascript,postgresql,my sql,css framework
# 13324                                               test

# %%
u_n
# Out:
# '14.186.104.233, 10.122.10.10'
